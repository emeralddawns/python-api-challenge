# %% [markdown]
# # Weatherpy
# ----

# %% [markdown]
# ## Observed Trends

# %% [markdown]
# The following has been observed in the data:
#
# 1) The majority of cities appear to have humidity levels above 60%.  This may be due to major cities tending to be located near water sources, which increase the humidity of surrounding areas.
#
# 2) The northern hemisphere has a strong negative correlation between maximum temperature and latitude, while the southern atmosphere has a negative correlation.  Temperatures trend higher closer to the equator (latitude 0) because the equator and surrounding regions receive the greatest amount of direct sunlight. The northern hemisphere is currently angled away from the sun (causing overall cooler temperatures), while the southern hemisphere is angled toward the sun (causing overall warmer temperatures).
#
# 3) The other attributes looked at (humidity, cloudiness, and wind speed) had fairly weak correlations to latitude. This is likely because those three attributes have various other presiding factors, such as altitude and topography.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities from citipy
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
city_count = len(cities)
print(f" There are {city_count} cities in the list.")
# Out:
#  There are 632 cities in the list.

# %% [markdown]
# ## Perform API Calls

# %%
#Gather weather data from openweathermap api and fill the appropriate lists
weatherCities = []
lat = []
lon = []
temp = []
hum = []
cloud = []
wspeed = []
country = []
edate = []

#Set up the url information
weather_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{weather_url}appid={weather_api_key}&units={units}&q="

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        weatherCities.append(response["name"])
        country.append(response["sys"]["country"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"]) #the starter code refers to "Max Temp", not "Temp"
        hum.append(response["main"]["humidity"])
        cloud.append(response["clouds"]["all"])
        wspeed.append(response["wind"]["speed"])
        edate.append(response["dt"])
        
        index = cities.index(city)
        print(f"Processing record {index + 1} of {city_count} | {city}") 
        
    except (KeyError, IndexError): 
        print(f"City {city} not found. Skipping City.")
        pass
# Out:
# Processing record 1 of 632 | cape town
# Processing record 2 of 632 | busselton
# Processing record 3 of 632 | port elizabeth
# Processing record 4 of 632 | ribeira grande
# Processing record 5 of 632 | cayenne
# Processing record 6 of 632 | jamestown
# Processing record 7 of 632 | georgetown
# Processing record 8 of 632 | mar del plata
# Processing record 9 of 632 | honningsvag
# Processing record 10 of 632 | punta arenas
# Processing record 11 of 632 | sao filipe
# Processing record 12 of 632 | new norfolk
# City warqla not found. Skipping City.
# Processing record 14 of 632 | hilo
# Processing record 15 of 632 | aklavik
# Processing record 16 of 632 | atuona
# Processing record 17 of 632 | kavieng
# Processing record 18 of 632 | rikitea
# Processing record 19 of 632 | lompoc
# Processing record 20 of 632 | bluff
# Processing record 21 of 632 | talara
# Processing record 22 of 632 | puerto escondido
# Processing record 23 of 632 | tornio
# Processing record 24 of 632 | port hedland
# Processing record 25 of 632 | abu dhabi
# City kamenskoye not found. Skipping City.
# Processing record 27 of 632 | saint-georges
# Processing record 28 of 632 | fort nelson
# Processing record 29 of 632 | omsukchan
# Processing record 30 of 632 | katsuura
# City taolanaro not found. Skipping City.
# Processing record 32 of 632 | saint-philippe
# Processing record 33 of 632 | ushuaia
# Processing record 34 of 632 | saskylakh
# Processing record 35 of 632 | san patricio
# Processing record 36 of 632 | honiara
# City illoqqortoormiut not found. Skipping City.
# Processing record 38 of 632 | lypova dolyna
# Processing record 39 of 632 | la ronge
# Processing record 40 of 632 | murupara
# Processing record 41 of 632 | eenhana
# Processing record 42 of 632 | spencer
# Processing record 43 of 632 | flinders
# Processing record 44 of 632 | port alfred
# City cockburn harbour not found. Skipping City.
# Processing record 46 of 632 | airai
# Processing record 47 of 632 | provideniya
# Processing record 48 of 632 | weligama
# Processing record 49 of 632 | popondetta
# Processing record 50 of 632 | ekibastuz
# Processing record 51 of 632 | castro
# Processing record 52 of 632 | mataura
# Processing record 53 of 632 | hithadhoo
# Processing record 54 of 632 | coquimbo
# Processing record 55 of 632 | sitka
# Processing record 56 of 632 | formosa
# City attawapiskat not found. Skipping City.
# Processing record 58 of 632 | muriwai beach
# Processing record 59 of 632 | guerrero negro
# Processing record 60 of 632 | avarua
# Processing record 61 of 632 | hobart
# Processing record 62 of 632 | cacequi
# City ruatoria not found. Skipping City.
# Processing record 64 of 632 | bredasdorp
# Processing record 65 of 632 | wanning
# Processing record 66 of 632 | coihaique
# Processing record 67 of 632 | iqaluit
# Processing record 68 of 632 | bubaque
# Processing record 69 of 632 | garango
# Processing record 70 of 632 | tarata
# Processing record 71 of 632 | kahului
# Processing record 72 of 632 | paso del toro
# City fulitun not found. Skipping City.
# Processing record 74 of 632 | lavrentiya
# Processing record 75 of 632 | bressuire
# Processing record 76 of 632 | nyurba
# Processing record 77 of 632 | ahipara
# Processing record 78 of 632 | kolomna
# Processing record 79 of 632 | grindavik
# City vaitupu not found. Skipping City.
# City eldikan not found. Skipping City.
# Processing record 82 of 632 | haizhou
# Processing record 83 of 632 | esperance
# Processing record 84 of 632 | muros
# Processing record 85 of 632 | san carlos de bariloche
# Processing record 86 of 632 | qaanaaq
# Processing record 87 of 632 | harbour breton
# Processing record 88 of 632 | tiarei
# Processing record 89 of 632 | garden city
# Processing record 90 of 632 | butaritari
# City hihifo not found. Skipping City.
# Processing record 92 of 632 | vaini
# Processing record 93 of 632 | hermanus
# Processing record 94 of 632 | chakulia
# Processing record 95 of 632 | mitu
# Processing record 96 of 632 | makakilo city
# City samusu not found. Skipping City.
# City belushya guba not found. Skipping City.
# Processing record 99 of 632 | leningradskiy
# Processing record 100 of 632 | kemise
# City hunza not found. Skipping City.
# Processing record 102 of 632 | fare
# Processing record 103 of 632 | hofn
# Processing record 104 of 632 | yarada
# Processing record 105 of 632 | ponta do sol
# Processing record 106 of 632 | primorsko-akhtarsk
# Processing record 107 of 632 | kruisfontein
# Processing record 108 of 632 | puerto ayora
# Processing record 109 of 632 | barrow
# Processing record 110 of 632 | malkangiri
# Processing record 111 of 632 | tasiilaq
# City grand river south east not found. Skipping City.
# Processing record 113 of 632 | upernavik
# Processing record 114 of 632 | portland
# Processing record 115 of 632 | adrar
# Processing record 116 of 632 | charlestown
# Processing record 117 of 632 | tiksi
# Processing record 118 of 632 | igarka
# Processing record 119 of 632 | masaki
# Processing record 120 of 632 | san agustin
# Processing record 121 of 632 | strathmore
# Processing record 122 of 632 | yellowknife
# Processing record 123 of 632 | beringovskiy
# Processing record 124 of 632 | plouzane
# Processing record 125 of 632 | kataysk
# Processing record 126 of 632 | sande
# Processing record 127 of 632 | torbay
# City mys shmidta not found. Skipping City.
# Processing record 129 of 632 | nokaneng
# Processing record 130 of 632 | calama
# Processing record 131 of 632 | port-gentil
# City tawkar not found. Skipping City.
# Processing record 133 of 632 | nazarovo
# Processing record 134 of 632 | victoria
# City phan rang not found. Skipping City.
# Processing record 136 of 632 | roma
# Processing record 137 of 632 | raudeberg
# Processing record 138 of 632 | novoagansk
# Processing record 139 of 632 | fairbanks
# Processing record 140 of 632 | terrace
# Processing record 141 of 632 | okhotsk
# Processing record 142 of 632 | barra patuca
# Processing record 143 of 632 | johnson city
# Processing record 144 of 632 | ende
# Processing record 145 of 632 | thompson
# City tsihombe not found. Skipping City.
# Processing record 147 of 632 | koygorodok
# Processing record 148 of 632 | bandarbeyla
# Processing record 149 of 632 | sampang
# Processing record 150 of 632 | kushima
# Processing record 151 of 632 | souillac
# Processing record 152 of 632 | saldanha
# City galgani not found. Skipping City.
# Processing record 154 of 632 | saint-gaudens
# City nizhneyansk not found. Skipping City.
# City umm durman not found. Skipping City.
# Processing record 157 of 632 | general pico
# Processing record 158 of 632 | arraial do cabo
# Processing record 159 of 632 | ravar
# Processing record 160 of 632 | chuy
# Processing record 161 of 632 | harnosand
# Processing record 162 of 632 | ahuimanu
# Processing record 163 of 632 | colac
# City scottsburgh not found. Skipping City.
# Processing record 165 of 632 | maragogi
# Processing record 166 of 632 | longyearbyen
# Processing record 167 of 632 | vestmannaeyjar
# Processing record 168 of 632 | guaymas
# Processing record 169 of 632 | puerto leguizamo
# City ust-kamchatsk not found. Skipping City.
# City tasbuget not found. Skipping City.
# Processing record 172 of 632 | vila
# Processing record 173 of 632 | tuktoyaktuk
# Processing record 174 of 632 | nikolskoye
# Processing record 175 of 632 | shakawe
# Processing record 176 of 632 | carnarvon
# Processing record 177 of 632 | monroe
# Processing record 178 of 632 | pevek
# Processing record 179 of 632 | horni becva
# Processing record 180 of 632 | pyu
# Processing record 181 of 632 | tarancon
# Processing record 182 of 632 | clyde river
# Processing record 183 of 632 | cabedelo
# Processing record 184 of 632 | palu
# Processing record 185 of 632 | tessalit
# Processing record 186 of 632 | yar-sale
# Processing record 187 of 632 | saint-francois
# Processing record 188 of 632 | wahiawa
# Processing record 189 of 632 | wasilla
# Processing record 190 of 632 | astoria
# Processing record 191 of 632 | yarkovo
# Processing record 192 of 632 | bardiyah
# Processing record 193 of 632 | meulaboh
# Processing record 194 of 632 | patterson
# Processing record 195 of 632 | barentu
# Processing record 196 of 632 | gat
# Processing record 197 of 632 | avera
# Processing record 198 of 632 | east london
# Processing record 199 of 632 | wuchang
# Processing record 200 of 632 | tungor
# Processing record 201 of 632 | vostok
# Processing record 202 of 632 | lagoa
# Processing record 203 of 632 | seoul
# Processing record 204 of 632 | cabo san lucas
# Processing record 205 of 632 | ambanja
# Processing record 206 of 632 | sambava
# Processing record 207 of 632 | porto velho
# City sentyabrskiy not found. Skipping City.
# Processing record 209 of 632 | davlekanovo
# Processing record 210 of 632 | lokosovo
# Processing record 211 of 632 | dakar
# Processing record 212 of 632 | gambela
# Processing record 213 of 632 | stromness
# Processing record 214 of 632 | laguna
# Processing record 215 of 632 | bambous virieux
# Processing record 216 of 632 | jalu
# City chagda not found. Skipping City.
# Processing record 218 of 632 | kodiak
# Processing record 219 of 632 | palmer
# Processing record 220 of 632 | coxim
# Processing record 221 of 632 | albany
# Processing record 222 of 632 | yuli
# Processing record 223 of 632 | khatanga
# Processing record 224 of 632 | chachapoyas
# Processing record 225 of 632 | timizart
# Processing record 226 of 632 | micheweni
# Processing record 227 of 632 | mount isa
# Processing record 228 of 632 | kaitangata
# Processing record 229 of 632 | maceio
# Processing record 230 of 632 | lata
# Processing record 231 of 632 | maues
# Processing record 232 of 632 | polignano a mare
# Processing record 233 of 632 | talnakh
# Processing record 234 of 632 | blagodatnoye
# Processing record 235 of 632 | riyadh
# City solovetskiy not found. Skipping City.
# Processing record 237 of 632 | pisco
# Processing record 238 of 632 | monchique
# City bacuit not found. Skipping City.
# Processing record 240 of 632 | dikson
# Processing record 241 of 632 | matara
# Processing record 242 of 632 | kumo
# City mithimna not found. Skipping City.
# Processing record 244 of 632 | champerico
# Processing record 245 of 632 | kencong
# Processing record 246 of 632 | abu zabad
# Processing record 247 of 632 | kota
# Processing record 248 of 632 | sault sainte marie
# Processing record 249 of 632 | aiken
# Processing record 250 of 632 | mackay
# City aflu not found. Skipping City.
# Processing record 252 of 632 | serebryansk
# Processing record 253 of 632 | sinnamary
# City tumannyy not found. Skipping City.
# Processing record 255 of 632 | matamoros
# Processing record 256 of 632 | la rioja
# Processing record 257 of 632 | bantou
# Processing record 258 of 632 | kokstad
# City kawana waters not found. Skipping City.
# Processing record 260 of 632 | birjand
# Processing record 261 of 632 | carutapera
# Processing record 262 of 632 | port macquarie
# Processing record 263 of 632 | lubliniec
# Processing record 264 of 632 | santa cruz
# Processing record 265 of 632 | youghal
# Processing record 266 of 632 | nargana
# Processing record 267 of 632 | paamiut
# City lolua not found. Skipping City.
# City amderma not found. Skipping City.
# Processing record 270 of 632 | gillette
# Processing record 271 of 632 | hede
# Processing record 272 of 632 | bosaso
# Processing record 273 of 632 | phalombe
# Processing record 274 of 632 | sabzevar
# Processing record 275 of 632 | namatanai
# Processing record 276 of 632 | codrington
# Processing record 277 of 632 | eydhafushi
# Processing record 278 of 632 | camapua
# Processing record 279 of 632 | faya
# Processing record 280 of 632 | asau
# Processing record 281 of 632 | kantunilkin
# Processing record 282 of 632 | san vicente
# Processing record 283 of 632 | juneau
# Processing record 284 of 632 | luderitz
# Processing record 285 of 632 | lovozero
# Processing record 286 of 632 | daye
# Processing record 287 of 632 | cidreira
# Processing record 288 of 632 | ngorongoro
# Processing record 289 of 632 | samarai
# Processing record 290 of 632 | saint-joseph
# Processing record 291 of 632 | ancud
# Processing record 292 of 632 | klaksvik
# Processing record 293 of 632 | strai
# Processing record 294 of 632 | lebu
# Processing record 295 of 632 | lasa
# Processing record 296 of 632 | okha
# Processing record 297 of 632 | emerald
# Processing record 298 of 632 | townsville
# Processing record 299 of 632 | todos santos
# Processing record 300 of 632 | fillan
# Processing record 301 of 632 | tyler
# Processing record 302 of 632 | porosozero
# Processing record 303 of 632 | songjianghe
# City cumaribo not found. Skipping City.
# Processing record 305 of 632 | chulman
# Processing record 306 of 632 | xunchang
# Processing record 307 of 632 | ilulissat
# Processing record 308 of 632 | khor
# Processing record 309 of 632 | mahon
# Processing record 310 of 632 | nantucket
# Processing record 311 of 632 | outjo
# City stoyba not found. Skipping City.
# City barentsburg not found. Skipping City.
# Processing record 314 of 632 | sangar
# Processing record 315 of 632 | san luis
# Processing record 316 of 632 | grand gaube
# Processing record 317 of 632 | zhigalovo
# City okandja not found. Skipping City.
# Processing record 319 of 632 | norman wells
# Processing record 320 of 632 | lusambo
# Processing record 321 of 632 | nocupetaro
# Processing record 322 of 632 | cherskiy
# Processing record 323 of 632 | severo-kurilsk
# Processing record 324 of 632 | lincoln
# Processing record 325 of 632 | sinop
# City nguiu not found. Skipping City.
# Processing record 327 of 632 | tura
# Processing record 328 of 632 | maltahohe
# Processing record 329 of 632 | dondo
# City jiddah not found. Skipping City.
# Processing record 331 of 632 | sterling
# Processing record 332 of 632 | touros
# Processing record 333 of 632 | qui nhon
# Processing record 334 of 632 | villa hayes
# Processing record 335 of 632 | yinchuan
# Processing record 336 of 632 | hasaki
# Processing record 337 of 632 | gap
# Processing record 338 of 632 | kudahuvadhoo
# Processing record 339 of 632 | babushkin
# Processing record 340 of 632 | mahebourg
# Processing record 341 of 632 | mungaa
# Processing record 342 of 632 | pangnirtung
# Processing record 343 of 632 | les cayes
# Processing record 344 of 632 | kabanjahe
# Processing record 345 of 632 | hambantota
# Processing record 346 of 632 | najran
# Processing record 347 of 632 | wakkanai
# Processing record 348 of 632 | pacific grove
# Processing record 349 of 632 | kirakira
# Processing record 350 of 632 | pemangkat
# Processing record 351 of 632 | san jeronimo
# Processing record 352 of 632 | mehamn
# Processing record 353 of 632 | cowra
# Processing record 354 of 632 | san ramon
# Processing record 355 of 632 | mayo
# Processing record 356 of 632 | reconquista
# Processing record 357 of 632 | nome
# Processing record 358 of 632 | jieshi
# Processing record 359 of 632 | college
# Processing record 360 of 632 | cao bang
# Processing record 361 of 632 | dubrovnik
# Processing record 362 of 632 | kuryk
# Processing record 363 of 632 | antsohihy
# Processing record 364 of 632 | pokhara
# Processing record 365 of 632 | ranong
# Processing record 366 of 632 | marsh harbour
# Processing record 367 of 632 | koslan
# Processing record 368 of 632 | nanortalik
# Processing record 369 of 632 | tete
# Processing record 370 of 632 | vao
# Processing record 371 of 632 | chicama
# Processing record 372 of 632 | kapaa
# Processing record 373 of 632 | bengkulu
# Processing record 374 of 632 | batticaloa
# Processing record 375 of 632 | baijiantan
# Processing record 376 of 632 | saint-pierre
# Processing record 377 of 632 | remedios
# Processing record 378 of 632 | inuvik
# Processing record 379 of 632 | pochutla
# Processing record 380 of 632 | hami
# Processing record 381 of 632 | alofi
# Processing record 382 of 632 | haines junction
# Processing record 383 of 632 | askarovo
# Processing record 384 of 632 | vigia del fuerte
# Processing record 385 of 632 | srednekolymsk
# Processing record 386 of 632 | dunedin
# Processing record 387 of 632 | bukachacha
# Processing record 388 of 632 | chokurdakh
# Processing record 389 of 632 | camacha
# Processing record 390 of 632 | morehead
# Processing record 391 of 632 | alaca
# Processing record 392 of 632 | egvekinot
# Processing record 393 of 632 | broome
# Processing record 394 of 632 | datong
# Processing record 395 of 632 | tortoli
# Processing record 396 of 632 | salalah
# Processing record 397 of 632 | mana
# Processing record 398 of 632 | aleksandrov gay
# City witrivier not found. Skipping City.
# Processing record 400 of 632 | turkmenabat
# Processing record 401 of 632 | tottori
# City rungata not found. Skipping City.
# Processing record 403 of 632 | richards bay
# Processing record 404 of 632 | nakhon phanom
# City oreanda not found. Skipping City.
# Processing record 406 of 632 | lawrenceburg
# Processing record 407 of 632 | san pedro
# Processing record 408 of 632 | lorengau
# Processing record 409 of 632 | olafsvik
# Processing record 410 of 632 | lodja
# Processing record 411 of 632 | uruzgan
# Processing record 412 of 632 | vangaindrano
# Processing record 413 of 632 | anori
# Processing record 414 of 632 | pangai
# Processing record 415 of 632 | husavik
# Processing record 416 of 632 | jiangyou
# Processing record 417 of 632 | saravan
# Processing record 418 of 632 | anadyr
# Processing record 419 of 632 | santiago
# Processing record 420 of 632 | jalingo
# Processing record 421 of 632 | tokat
# Processing record 422 of 632 | waipawa
# Processing record 423 of 632 | zabid
# Processing record 424 of 632 | ankazoabo
# Processing record 425 of 632 | verkhnyaya inta
# Processing record 426 of 632 | lebork
# Processing record 427 of 632 | zurrieq
# Processing record 428 of 632 | damietta
# Processing record 429 of 632 | tahta
# Processing record 430 of 632 | clonakilty
# Processing record 431 of 632 | nenjiang
# City saleaula not found. Skipping City.
# Processing record 433 of 632 | songea
# Processing record 434 of 632 | balabac
# City toliary not found. Skipping City.
# Processing record 436 of 632 | grand-santi
# Processing record 437 of 632 | mirante do paranapanema
# Processing record 438 of 632 | beloha
# Processing record 439 of 632 | bodden town
# Processing record 440 of 632 | rio gallegos
# Processing record 441 of 632 | chau doc
# Processing record 442 of 632 | brae
# Processing record 443 of 632 | tual
# Processing record 444 of 632 | maniitsoq
# Processing record 445 of 632 | kurchum
# Processing record 446 of 632 | bartow
# City rolim de moura not found. Skipping City.
# Processing record 448 of 632 | novyy urengoy
# Processing record 449 of 632 | acarau
# Processing record 450 of 632 | mayumba
# Processing record 451 of 632 | saint-agapit
# Processing record 452 of 632 | dogondoutchi
# Processing record 453 of 632 | necochea
# Processing record 454 of 632 | geraldton
# Processing record 455 of 632 | port lincoln
# City taburi not found. Skipping City.
# Processing record 457 of 632 | batemans bay
# City shchelyayur not found. Skipping City.
# Processing record 459 of 632 | kaset sombun
# Processing record 460 of 632 | te anau
# Processing record 461 of 632 | tall kayf
# Processing record 462 of 632 | isangel
# Processing record 463 of 632 | muisne
# Processing record 464 of 632 | alice springs
# Processing record 465 of 632 | ouadda
# Processing record 466 of 632 | bang saphan
# Processing record 467 of 632 | novokayakent
# Processing record 468 of 632 | skjervoy
# Processing record 469 of 632 | leh
# Processing record 470 of 632 | goderich
# Processing record 471 of 632 | antofagasta
# Processing record 472 of 632 | lock haven
# Processing record 473 of 632 | biak
# Processing record 474 of 632 | bac lieu
# Processing record 475 of 632 | bulancak
# Processing record 476 of 632 | basco
# City we not found. Skipping City.
# Processing record 478 of 632 | katobu
# City mouzakion not found. Skipping City.
# Processing record 480 of 632 | amapa
# Processing record 481 of 632 | shingu
# Processing record 482 of 632 | chapais
# Processing record 483 of 632 | krasnoye
# Processing record 484 of 632 | san julian
# Processing record 485 of 632 | san policarpo
# Processing record 486 of 632 | bluffton
# Processing record 487 of 632 | faanui
# Processing record 488 of 632 | half moon bay
# Processing record 489 of 632 | marystown
# Processing record 490 of 632 | atbasar
# Processing record 491 of 632 | staryy nadym
# Processing record 492 of 632 | freetown
# Processing record 493 of 632 | fort-shevchenko
# Processing record 494 of 632 | noumea
# Processing record 495 of 632 | challapata
# Processing record 496 of 632 | illapel
# Processing record 497 of 632 | sosnovskoye
# Processing record 498 of 632 | sorland
# Processing record 499 of 632 | urusha
# Processing record 500 of 632 | skibbereen
# Processing record 501 of 632 | sorong
# Processing record 502 of 632 | tobol
# Processing record 503 of 632 | dareda
# Processing record 504 of 632 | cartagena
# Processing record 505 of 632 | guangyuan
# Processing record 506 of 632 | marsa matruh
# Processing record 507 of 632 | ust-tsilma
# Processing record 508 of 632 | artyom
# Processing record 509 of 632 | dhidhdhoo
# Processing record 510 of 632 | doha
# Processing record 511 of 632 | tuatapere
# Processing record 512 of 632 | marawi
# City andevoranto not found. Skipping City.
# Processing record 514 of 632 | tiznit
# Processing record 515 of 632 | ploemeur
# Processing record 516 of 632 | magdalena
# City tarudant not found. Skipping City.
# Processing record 518 of 632 | alihe
# Processing record 519 of 632 | numan
# Processing record 520 of 632 | gornopravdinsk
# Processing record 521 of 632 | acari
# Processing record 522 of 632 | batagay
# Processing record 523 of 632 | matagami
# Processing record 524 of 632 | kem
# Processing record 525 of 632 | shimoda
# Processing record 526 of 632 | huarmey
# Processing record 527 of 632 | raahe
# Processing record 528 of 632 | san quintin
# Processing record 529 of 632 | kurilsk
# Processing record 530 of 632 | karasburg
# Processing record 531 of 632 | sakakah
# City jujuy not found. Skipping City.
# Processing record 533 of 632 | jasper
# Processing record 534 of 632 | milos
# Processing record 535 of 632 | port blair
# Processing record 536 of 632 | coihueco
# Processing record 537 of 632 | nishihara
# Processing record 538 of 632 | russell
# Processing record 539 of 632 | magway
# Processing record 540 of 632 | constitucion
# Processing record 541 of 632 | tshikapa
# Processing record 542 of 632 | dandong
# Processing record 543 of 632 | eureka
# Processing record 544 of 632 | kavaratti
# Processing record 545 of 632 | tilichiki
# City shibarghan not found. Skipping City.
# Processing record 547 of 632 | anloga
# Processing record 548 of 632 | henties bay
# Processing record 549 of 632 | redditch
# City khrustalnyy not found. Skipping City.
# City tambul not found. Skipping City.
# Processing record 552 of 632 | baculin
# Processing record 553 of 632 | soure
# Processing record 554 of 632 | toguchin
# Processing record 555 of 632 | rocha
# Processing record 556 of 632 | kolaras
# Processing record 557 of 632 | devrek
# Processing record 558 of 632 | omboue
# Processing record 559 of 632 | bonavista
# Processing record 560 of 632 | pijijiapan
# Processing record 561 of 632 | biltine
# Processing record 562 of 632 | wattegama
# City marcona not found. Skipping City.
# Processing record 564 of 632 | baykalsk
# Processing record 565 of 632 | san martin
# Processing record 566 of 632 | beatrice
# Processing record 567 of 632 | andenes
# Processing record 568 of 632 | didam
# Processing record 569 of 632 | harper
# Processing record 570 of 632 | bahir dar
# Processing record 571 of 632 | kyren
# Processing record 572 of 632 | inirida
# Processing record 573 of 632 | manggar
# Processing record 574 of 632 | axim
# Processing record 575 of 632 | poum
# Processing record 576 of 632 | kishapu
# Processing record 577 of 632 | kangaatsiaq
# Processing record 578 of 632 | pangody
# Processing record 579 of 632 | mersin
# Processing record 580 of 632 | sakaiminato
# Processing record 581 of 632 | bethel
# City artyk not found. Skipping City.
# Processing record 583 of 632 | oranjemund
# Processing record 584 of 632 | nioki
# Processing record 585 of 632 | altay
# Processing record 586 of 632 | magadi
# Processing record 587 of 632 | barabinsk
# City bolshiye uki not found. Skipping City.
# Processing record 589 of 632 | presidencia roque saenz pena
# Processing record 590 of 632 | bathsheba
# Processing record 591 of 632 | kungurtug
# Processing record 592 of 632 | surt
# City umzimvubu not found. Skipping City.
# Processing record 594 of 632 | seleron
# Processing record 595 of 632 | general roca
# Processing record 596 of 632 | zaraza
# Processing record 597 of 632 | gizo
# Processing record 598 of 632 | sioux lookout
# Processing record 599 of 632 | olbia
# Processing record 600 of 632 | la libertad
# Processing record 601 of 632 | luangwa
# Processing record 602 of 632 | norden
# Processing record 603 of 632 | vaitape
# Processing record 604 of 632 | itarema
# Processing record 605 of 632 | pishva
# Processing record 606 of 632 | tigil
# Processing record 607 of 632 | nanakuli
# Processing record 608 of 632 | cassilandia
# Processing record 609 of 632 | wuwei
# Processing record 610 of 632 | berlevag
# Processing record 611 of 632 | kamenka
# Processing record 612 of 632 | lakhipur
# Processing record 613 of 632 | panama city
# Processing record 614 of 632 | villa rica
# Processing record 615 of 632 | mount gambier
# Processing record 616 of 632 | aksu
# Processing record 617 of 632 | vanimo
# Processing record 618 of 632 | wamba
# Processing record 619 of 632 | dulovo
# Processing record 620 of 632 | hoi an
# Processing record 621 of 632 | bilibino
# Processing record 622 of 632 | termoli
# Processing record 623 of 632 | quatre cocos
# Processing record 624 of 632 | dekernes
# Processing record 625 of 632 | yeniseysk
# Processing record 626 of 632 | zephyrhills
# City jinchengjiang not found. Skipping City.
# City yanan not found. Skipping City.
# Processing record 629 of 632 | maneadero
# Processing record 630 of 632 | srandakan
# Processing record 631 of 632 | yanam
# Processing record 632 of 632 | fallon

# %% [markdown]
# ## Convert Raw Data to DataFrame

# %%
#Create the dictionary of weather information for each city, and then convert to data frame and display    
weather_dict = {
    "City": weatherCities,
    "Country": country,
    "Latitude": lat,
    "Longitude": lon,
    "Max Temp (F)": temp,
    "Humidity (%)": hum,
    "Cloudiness (%)": cloud,
    "Wind Speed (mph)": wspeed,
    "Date": edate
}
#Save the city weather data as a data frame
weather_data = pd.DataFrame(weather_dict)

# %%
#Clean the data frame by removing any entries with humidity levels over 100%
weather_data_cl = weather_data[weather_data["Humidity (%)"] <= 100]
weather_data_cl.index.name = "City ID"

#Store the first date to label all the plots
start_time = weather_data_cl["Date"].iloc[0]
date = time.strftime('%m-%d-%Y', time.localtime(start_time))

#Convert epoch time into CST
weather_data_cl["Date"] = pd.to_datetime(weather_data_cl["Date"], unit='s', utc=True).dt.tz_convert('US/Central')

#Save the city weather data as a csv
weather_data_cl.to_csv("output_data/cities.csv", sep=',', encoding='utf-8')

#Display the cleaned and formatted data frame
weather_data_cl.head()
# Out:
#                    City Country  Latitude  Longitude  Max Temp (F)  \
# City ID
# 0             Cape Town      ZA  -33.9258    18.4232         67.08
# 1             Busselton      AU  -33.6500   115.3333         56.05
# 2        Port Elizabeth      ZA  -33.9180    25.5701         62.89
# 3        Ribeira Grande      PT   38.5167   -28.7000         60.35
# 4               Cayenne      GF    4.9333   -52.3333         80.10
#
#          Humidity (%)  Cloudiness (%)  Wind Speed (mph)  \
# City ID
# 0                  80              67              1.66
# 1                  76               3              6.11
# 2                  94              20              9.22
# 3                  70              93              5.95
# 4                  84              20              4.00
#
#                              Date
# City ID
# 0       2022-02-08 17:07:14-06:00
# 1       2022-02-08 17:07:16-06:00
# 2       2022-02-08 17:07:16-06:00
# 3       2022-02-08 17:07:16-06:00
# 4       2022-02-08 17:07:16-06:00

# %% [markdown]
# ## Plotting the Data

# %%
#Define a function that will create a scatter plot and save it
def scattered(xlabel, ylabel, lat_range, date, savename):
    plt.figure()
    plt.scatter(weather_data_cl[xlabel], weather_data_cl[ylabel], marker = "o", facecolors="skyblue", edgecolors="black")
    plt.grid()
    plt.xlabel(xlabel)
    plt.xlim(lat_range[0], lat_range[1])
    plt.ylabel(ylabel)
    plt.title(f"{ylabel} vs {xlabel} ({date})")
    
    #Save the figure
    plt.savefig("output_data/"+ savename)
    
    #Display the figure
    plt.show()

# %%
# Temperature (F) vs. Latitude

#Define plot specific information
xlabel = "Latitude"
ylabel = "Max Temp (F)"
savename = "MaxTvsLat"

#Call on the user-defined scattered function
scattered(xlabel, ylabel, lat_range, date, savename)

print(f" The plot above is analysing the relationship between {ylabel} and {xlabel}.")
print(f" Based on the plot, there does appear to be a relationship between Max Temp (F) and Latitude")
# Out:
#  The plot above is analysing the relationship between Max Temp (F) and Latitude.
#  Based on the plot, there does appear to be a relationship between Max Temp (F) and Latitude

# %%
# Humidity (%) vs. Latitude

#Define plot specific information
xlabel = "Latitude"
ylabel = "Humidity (%)"
savename = "HumVsLat"

#Call on the user-defined scattered function
scattered(xlabel, ylabel, lat_range, date, savename)

print(f" The plot above is analysing the relationship between {ylabel} and {xlabel}.")
print(f" Based on the plot, many of the cities found tend to have higher (greater than 60%) humidity.")
print(f" This may be due to most major cities being located near water sources.")
# Out:
#  The plot above is analysing the relationship between Humidity (%) and Latitude.
#  Based on the plot, many of the cities found tend to have higher (greater than 60%) humidity.
#  This may be due to most major cities being located near water sources.

# %%
# Cloudiness (%) vs. Latitude

#Define plot specific information
xlabel = "Latitude"
ylabel = "Cloudiness (%)"
savename = "CloudVsLat"

#Call on the user-defined scattered function
scattered(xlabel, ylabel, lat_range, date, savename)

print(f" The plot above is analysing the relationship between {ylabel} and {xlabel}.")
print(f" Based on the plot, the relationship between Cloudiness (%) and Latitude is likely weak.")
# Out:
#  The plot above is analysing the relationship between Cloudiness (%) and Latitude.
#  Based on the plot, the relationship between Cloudiness (%) and Latitude is likely weak.

# %%
# Wind Speed (mph) vs. Latitude

#Define plot specific information
xlabel = "Latitude"
ylabel = "Wind Speed (mph)"
savename = "WSpdVsLat"

#Call on the user-defined scattered function
scattered(xlabel, ylabel, lat_range, date, savename)

print(f" The plot above is analysing the relationship between {ylabel} and {xlabel}.")
print(f" Based on the plot, the relationship between Wind Speed (mph) and Latitude is likely weak.")
# Out:
#  The plot above is analysing the relationship between Wind Speed (mph) and Latitude.
#  Based on the plot, the relationship between Wind Speed (mph) and Latitude is likely weak.

# %% [markdown]
# ## Linear Regression

# %%
#Create separate data frames for the northern and southern hemispheres
north_weather_data = weather_data_cl[weather_data_cl["Latitude"] >= 0]
south_weather_data = weather_data_cl[weather_data_cl["Latitude"] < 0]

#Create a data frame for the xlim values for the scatter plots below
xaxis = pd.DataFrame({"Northern": (0, 80), "Southern": (-60, 0)})

# %%
#Define a function that will output the r-value, scatter plot, linear regression line, and linear regression equation

def linreg(hemisphere, xlabel, ylabel, annoloc, savename, date):

    if hemisphere == "Northern":
        xvalues = north_weather_data[xlabel]
        yvalues = north_weather_data[ylabel]
    else:     
        xvalues = south_weather_data[xlabel]
        yvalues = south_weather_data[ylabel]
        
    #Format the scatter plot
    plt.figure()
    plt.title(f"{hemisphere} Hemisphere: {ylabel} vs {xlabel} ({date})")
    xlim = xaxis[hemisphere] #pull the xlim values from a data frame
    plt.xlim(xlim)
    plt.scatter(xvalues, yvalues, marker = "o", facecolors="skyblue", edgecolors="black")
    plt.grid()
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    #Calculate everything needed for the linear regression line
    (slope, intercept, rvalue, pvalue, stdder) = linregress(xvalues, yvalues)
    line = slope * xvalues + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    #Format the linear regression line plot
    plt.plot(xvalues, line, color = "red")
    plt.annotate(line_eq, annoloc, fontsize = 15, color = "red")

    #Save the figure
    plt.savefig("output_data/"+ savename)
        
    #Show r-value and the plot
    print(f"The r-value is {round(rvalue, 4)}")
    plt.show();

# %%
# Northern Hemisphere - Temperature (F) vs. Latitude

#Define plot specific information
hemisphere = "Northern"
xlabel = "Latitude"
ylabel = "Max Temp (F)"
savename = "N_MaxTvsLat"
annoloc = (10,-20)   #annotation location for the linear regression equation

#Call on the user-defined linreg function
linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is -0.8476

# %% [markdown]
# In the northern hemisphere (which is currently in winter), there is currently a fairly strong negative correlation between Max Temp (F) and Latitude.
#
# Temperatures are higher near the equator (Latitude 0), owing to higher levels of direct sunlight.
#
# Temperatures at higher latitudes are lower to due to experiencing less direct sunlight, as the northern hemisphere is currently tilted away from the sun, causing more of the suns heat to reflect off of the atmosphere.

# %%
#Southern Hemisphere - Temperature (F) vs. Latitude

#Define plot specific information
hemisphere = "Southern"
xlabel = "Latitude"
ylabel = "Max Temp (F)"
savename = "S_MaxTvsLat"
annoloc = (-59,82)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.3671

# %% [markdown]
# In the southern hemisphere (which is currently in summer), there is currently a weak positive correlation between Max Temp (F) and Latitude.
#
# Temperatures are higher near the equator (Latitude 0), owing to higher levels of direct sunlight.

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude

#Define plot specific information
hemisphere = "Northern"
xlabel = "Latitude"
ylabel = "Humidity (%)"
savename = "N_HumVsLat"
annoloc = (45,20)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.3857

# %% [markdown]
# In the northern hemisphere, there is a weak positive correlation between humidity and latitude.

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude

#Define plot specific information
hemisphere = "Southern"
xlabel = "Latitude"
ylabel = "Humidity (%)"
savename = "S_HumVsLat"
annoloc = (-26,30)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.4392

# %% [markdown]
# In the southern hemispere, there is a weak positive correlation between humidity and latitude.

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude

#Define plot specific information
hemisphere = "Northern"
xlabel = "Latitude"
ylabel = "Cloudiness (%)"
savename = "N_CloudVsLat"
annoloc = (47,28)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.2448

# %% [markdown]
# In the northern hemisphere, there is a very weak positive correlation between cloudiness and latitude.

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude

#Define plot specific information
hemisphere = "Southern"
xlabel = "Latitude"
ylabel = "Cloudiness (%)"
savename = "S_CloudVsLat"
annoloc = (-55,80)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.2785

# %% [markdown]
# In the southern hemisphere, there is a very weak positive correlation between cloudiness and latitude.

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude

#Define plot specific information
hemisphere = "Northern"
xlabel = "Latitude"
ylabel = "Wind Speed (mph)"
savename = "N_WSpdVsLat"
annoloc = (10,30)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.2283

# %% [markdown]
# In the northern hemisphere, there is a very weak positive correlation between wind speed and latitude.

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude

#Define plot specific information
hemisphere = "Southern"
xlabel = "Latitude"
ylabel = "Wind Speed (mph)"
savename = "S_WSpdVsLat"
annoloc = (-55, 21)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is -0.1168

# %% [markdown]
# In the southern hemisphere, there is a very weak (possibly non-existent) negative correlation between wind speed and latitude.
