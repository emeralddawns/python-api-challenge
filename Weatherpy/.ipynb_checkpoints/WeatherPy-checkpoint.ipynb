# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities from citipy
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
city_count = len(cities)
city_count
# Out:
# 611

# %%
#Gather weather data from openweathermap api and fill the appropriate lists
weatherCities = []
lat = []
lon = []
temp = []
hum = []
cloud = []
wspeed = []
country = []
edate = []

#Set up the url information
weather_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{weather_url}appid={weather_api_key}&units={units}&q="

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        weatherCities.append(response["name"])
        country.append(response["sys"]["country"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"]) #the starter code refers to "Max Temp", not "Temp"
        hum.append(response["main"]["humidity"])
        cloud.append(response["clouds"]["all"])
        wspeed.append(response["wind"]["speed"])
        edate.append(response["dt"])
        
        index = cities.index(city)
        print(f"Processing record {index + 1} of {city_count} | {city}") 
        
    except (KeyError, IndexError): 
        print(f"City {city} not found. Skipping City.")
        pass
# Out:
# Processing record 1 of 611 | port lincoln
# Processing record 2 of 611 | lerwick
# Processing record 3 of 611 | aklavik
# Processing record 4 of 611 | bambanglipuro
# Processing record 5 of 611 | ushtobe
# Processing record 6 of 611 | raglan
# Processing record 7 of 611 | poum
# Processing record 8 of 611 | pevek
# Processing record 9 of 611 | atuona
# Processing record 10 of 611 | vaini
# Processing record 11 of 611 | sambava
# Processing record 12 of 611 | kapaa
# Processing record 13 of 611 | port alfred
# Processing record 14 of 611 | bilibino
# Processing record 15 of 611 | esso
# Processing record 16 of 611 | bluff
# Processing record 17 of 611 | tasiilaq
# Processing record 18 of 611 | broome
# Processing record 19 of 611 | iqaluit
# Processing record 20 of 611 | avarua
# Processing record 21 of 611 | khatanga
# Processing record 22 of 611 | isangel
# Processing record 23 of 611 | da nang
# City taolanaro not found. Skipping City.
# Processing record 25 of 611 | bredasdorp
# Processing record 26 of 611 | siavonga
# Processing record 27 of 611 | punta arenas
# Processing record 28 of 611 | bethel
# City marcona not found. Skipping City.
# Processing record 30 of 611 | fortuna
# Processing record 31 of 611 | piacabucu
# Processing record 32 of 611 | esik
# Processing record 33 of 611 | cockburn town
# Processing record 34 of 611 | saint-pierre
# Processing record 35 of 611 | thompson
# Processing record 36 of 611 | klaksvik
# City hihifo not found. Skipping City.
# Processing record 38 of 611 | eresos
# Processing record 39 of 611 | puerto colombia
# Processing record 40 of 611 | georgetown
# Processing record 41 of 611 | yellowknife
# Processing record 42 of 611 | folldal
# Processing record 43 of 611 | san rafael del sur
# Processing record 44 of 611 | fort-shevchenko
# Processing record 45 of 611 | zalantun
# Processing record 46 of 611 | pimentel
# Processing record 47 of 611 | jamestown
# Processing record 48 of 611 | souillac
# Processing record 49 of 611 | hermanus
# Processing record 50 of 611 | rengasdengklok
# Processing record 51 of 611 | jilib
# Processing record 52 of 611 | bandarbeyla
# Processing record 53 of 611 | evensk
# Processing record 54 of 611 | sanchazi
# Processing record 55 of 611 | ponta do sol
# Processing record 56 of 611 | puerto ayora
# Processing record 57 of 611 | san cristobal
# Processing record 58 of 611 | hofn
# Processing record 59 of 611 | margate
# City tsihombe not found. Skipping City.
# Processing record 61 of 611 | guajara
# Processing record 62 of 611 | ushuaia
# Processing record 63 of 611 | rikitea
# Processing record 64 of 611 | quatre cocos
# Processing record 65 of 611 | bentiu
# Processing record 66 of 611 | komsomolskiy
# Processing record 67 of 611 | constitucion
# Processing record 68 of 611 | wonthaggi
# Processing record 69 of 611 | kalabo
# City la uribe not found. Skipping City.
# Processing record 71 of 611 | wajima
# Processing record 72 of 611 | faanui
# Processing record 73 of 611 | darhan
# Processing record 74 of 611 | albany
# Processing record 75 of 611 | carnarvon
# Processing record 76 of 611 | emba
# Processing record 77 of 611 | winnemucca
# Processing record 78 of 611 | port hardy
# City barentsburg not found. Skipping City.
# Processing record 80 of 611 | sao joao da barra
# Processing record 81 of 611 | severo-kurilsk
# Processing record 82 of 611 | pisco
# City tocantinopolis not found. Skipping City.
# Processing record 84 of 611 | harindanga
# Processing record 85 of 611 | port elizabeth
# Processing record 86 of 611 | lagoa
# Processing record 87 of 611 | asfi
# Processing record 88 of 611 | new norfolk
# Processing record 89 of 611 | bac lieu
# Processing record 90 of 611 | busselton
# City belushya guba not found. Skipping City.
# Processing record 92 of 611 | fukue
# Processing record 93 of 611 | chokurdakh
# Processing record 94 of 611 | katsuura
# Processing record 95 of 611 | nome
# Processing record 96 of 611 | mataura
# Processing record 97 of 611 | ponta delgada
# Processing record 98 of 611 | cayenne
# Processing record 99 of 611 | wahpeton
# Processing record 100 of 611 | paraiso
# Processing record 101 of 611 | bima
# City mys shmidta not found. Skipping City.
# Processing record 103 of 611 | butaritari
# Processing record 104 of 611 | yala
# Processing record 105 of 611 | boone
# City illoqqortoormiut not found. Skipping City.
# Processing record 107 of 611 | vanimo
# Processing record 108 of 611 | ossora
# Processing record 109 of 611 | metro
# Processing record 110 of 611 | longyearbyen
# Processing record 111 of 611 | porbandar
# Processing record 112 of 611 | barrow
# Processing record 113 of 611 | berezovyy
# Processing record 114 of 611 | nikolskoye
# Processing record 115 of 611 | porto walter
# Processing record 116 of 611 | poya
# Processing record 117 of 611 | hobart
# Processing record 118 of 611 | kultuk
# Processing record 119 of 611 | victoria
# Processing record 120 of 611 | lorengau
# Processing record 121 of 611 | tura
# Processing record 122 of 611 | arraial do cabo
# Processing record 123 of 611 | kodiak
# Processing record 124 of 611 | cabo san lucas
# Processing record 125 of 611 | north bend
# City halalo not found. Skipping City.
# Processing record 127 of 611 | olafsvik
# Processing record 128 of 611 | makokou
# Processing record 129 of 611 | ribeira grande
# Processing record 130 of 611 | cidreira
# Processing record 131 of 611 | dolores
# Processing record 132 of 611 | kismayo
# Processing record 133 of 611 | east london
# Processing record 134 of 611 | xining
# Processing record 135 of 611 | provideniya
# Processing record 136 of 611 | kavieng
# Processing record 137 of 611 | bocas del toro
# Processing record 138 of 611 | yulara
# Processing record 139 of 611 | mishkino
# Processing record 140 of 611 | hilo
# Processing record 141 of 611 | russell
# Processing record 142 of 611 | alice springs
# Processing record 143 of 611 | kamloops
# Processing record 144 of 611 | quimper
# Processing record 145 of 611 | buala
# Processing record 146 of 611 | kambove
# Processing record 147 of 611 | namibe
# City tumannyy not found. Skipping City.
# Processing record 149 of 611 | san jose
# Processing record 150 of 611 | beringovskiy
# Processing record 151 of 611 | nova vicosa
# Processing record 152 of 611 | marawi
# Processing record 153 of 611 | portland
# Processing record 154 of 611 | wenatchee
# Processing record 155 of 611 | zhuhai
# Processing record 156 of 611 | mahibadhoo
# Processing record 157 of 611 | castilho
# Processing record 158 of 611 | yumen
# Processing record 159 of 611 | mnogovershinnyy
# Processing record 160 of 611 | fenoarivo atsinanana
# Processing record 161 of 611 | markala
# Processing record 162 of 611 | akyab
# Processing record 163 of 611 | sakakah
# City mergui not found. Skipping City.
# Processing record 165 of 611 | padang
# City amderma not found. Skipping City.
# Processing record 167 of 611 | nyagan
# Processing record 168 of 611 | richards bay
# Processing record 169 of 611 | baherden
# Processing record 170 of 611 | praia da vitoria
# City solovetskiy not found. Skipping City.
# Processing record 172 of 611 | waipawa
# Processing record 173 of 611 | tiarei
# Processing record 174 of 611 | lyuban
# Processing record 175 of 611 | jaca
# Processing record 176 of 611 | karratha
# Processing record 177 of 611 | cape town
# City makung not found. Skipping City.
# Processing record 179 of 611 | sungaipenuh
# Processing record 180 of 611 | atasu
# Processing record 181 of 611 | megion
# Processing record 182 of 611 | lompoc
# Processing record 183 of 611 | mandurah
# Processing record 184 of 611 | vila franca do campo
# Processing record 185 of 611 | touros
# Processing record 186 of 611 | buraydah
# Processing record 187 of 611 | kokopo
# Processing record 188 of 611 | cherskiy
# Processing record 189 of 611 | upernavik
# Processing record 190 of 611 | sur
# Processing record 191 of 611 | san patricio
# Processing record 192 of 611 | alamos
# Processing record 193 of 611 | cabra
# Processing record 194 of 611 | codrington
# Processing record 195 of 611 | aksarka
# Processing record 196 of 611 | amapa
# Processing record 197 of 611 | lahad datu
# Processing record 198 of 611 | henties bay
# Processing record 199 of 611 | kahului
# Processing record 200 of 611 | taoudenni
# Processing record 201 of 611 | yar-sale
# Processing record 202 of 611 | diffa
# Processing record 203 of 611 | geraldton
# Processing record 204 of 611 | nokha
# Processing record 205 of 611 | hithadhoo
# Processing record 206 of 611 | saskylakh
# Processing record 207 of 611 | dikson
# Processing record 208 of 611 | clyde river
# Processing record 209 of 611 | nara
# Processing record 210 of 611 | lamu
# Processing record 211 of 611 | sao goncalo do sapucai
# Processing record 212 of 611 | saint-philippe
# Processing record 213 of 611 | dicabisagan
# Processing record 214 of 611 | omboue
# Processing record 215 of 611 | marsa matruh
# Processing record 216 of 611 | bambous virieux
# Processing record 217 of 611 | mar del plata
# Processing record 218 of 611 | torbay
# Processing record 219 of 611 | praya
# Processing record 220 of 611 | lokosovo
# Processing record 221 of 611 | astoria
# Processing record 222 of 611 | zhengjiatun
# Processing record 223 of 611 | marsh harbour
# Processing record 224 of 611 | nabire
# Processing record 225 of 611 | braco do norte
# Processing record 226 of 611 | eyl
# Processing record 227 of 611 | batagay-alyta
# Processing record 228 of 611 | caarapo
# Processing record 229 of 611 | sabha
# Processing record 230 of 611 | college
# Processing record 231 of 611 | hambantota
# Processing record 232 of 611 | leningradskiy
# Processing record 233 of 611 | paranaiba
# Processing record 234 of 611 | hasaki
# City sentyabrskiy not found. Skipping City.
# Processing record 236 of 611 | tuy hoa
# Processing record 237 of 611 | beyneu
# Processing record 238 of 611 | erenhot
# Processing record 239 of 611 | riyadh
# Processing record 240 of 611 | mount gambier
# Processing record 241 of 611 | hamilton
# Processing record 242 of 611 | hami
# Processing record 243 of 611 | houston
# Processing record 244 of 611 | alcantara
# Processing record 245 of 611 | sitka
# Processing record 246 of 611 | cap malheureux
# Processing record 247 of 611 | strezhevoy
# Processing record 248 of 611 | bousso
# Processing record 249 of 611 | channel-port aux basques
# Processing record 250 of 611 | kavaratti
# Processing record 251 of 611 | saldanha
# Processing record 252 of 611 | dingle
# Processing record 253 of 611 | chuy
# City palabuhanratu not found. Skipping City.
# Processing record 255 of 611 | tecoanapa
# Processing record 256 of 611 | havelock
# Processing record 257 of 611 | toyooka
# Processing record 258 of 611 | golkoy
# Processing record 259 of 611 | iquique
# Processing record 260 of 611 | narsaq
# Processing record 261 of 611 | impfondo
# Processing record 262 of 611 | haines junction
# Processing record 263 of 611 | bengkulu
# Processing record 264 of 611 | diego de almagro
# Processing record 265 of 611 | comodoro rivadavia
# Processing record 266 of 611 | mtwara
# Processing record 267 of 611 | chimore
# Processing record 268 of 611 | chinsali
# Processing record 269 of 611 | tucumcari
# Processing record 270 of 611 | taltal
# Processing record 271 of 611 | lavrentiya
# Processing record 272 of 611 | uaua
# Processing record 273 of 611 | qaanaaq
# Processing record 274 of 611 | grand gaube
# City lolua not found. Skipping City.
# Processing record 276 of 611 | tuktoyaktuk
# Processing record 277 of 611 | bad kreuznach
# Processing record 278 of 611 | solnechnyy
# Processing record 279 of 611 | korla
# Processing record 280 of 611 | norrtalje
# Processing record 281 of 611 | avera
# Processing record 282 of 611 | qasigiannguit
# Processing record 283 of 611 | altamira
# Processing record 284 of 611 | mahebourg
# Processing record 285 of 611 | pueblo nuevo
# Processing record 286 of 611 | broken hill
# Processing record 287 of 611 | jalpa
# Processing record 288 of 611 | kruisfontein
# Processing record 289 of 611 | cowra
# Processing record 290 of 611 | jalu
# Processing record 291 of 611 | mumford
# Processing record 292 of 611 | adrar
# Processing record 293 of 611 | goundam
# Processing record 294 of 611 | puerto carreno
# Processing record 295 of 611 | tornio
# Processing record 296 of 611 | owando
# Processing record 297 of 611 | anamur
# Processing record 298 of 611 | kimbe
# Processing record 299 of 611 | wilmington
# Processing record 300 of 611 | kampong cham
# Processing record 301 of 611 | manaure
# Processing record 302 of 611 | finnsnes
# City attawapiskat not found. Skipping City.
# City samusu not found. Skipping City.
# Processing record 305 of 611 | kununurra
# Processing record 306 of 611 | ambilobe
# Processing record 307 of 611 | shimoda
# Processing record 308 of 611 | hwange
# Processing record 309 of 611 | mao
# Processing record 310 of 611 | kaitangata
# Processing record 311 of 611 | hervey bay
# Processing record 312 of 611 | lithakia
# Processing record 313 of 611 | nanortalik
# Processing record 314 of 611 | kloulklubed
# Processing record 315 of 611 | kirensk
# Processing record 316 of 611 | teocaltiche
# City riyaq not found. Skipping City.
# Processing record 318 of 611 | biak
# Processing record 319 of 611 | pacific grove
# Processing record 320 of 611 | coihaique
# Processing record 321 of 611 | kawalu
# Processing record 322 of 611 | tommot
# Processing record 323 of 611 | mykhaylivka
# Processing record 324 of 611 | semey
# City sukhoverkovo not found. Skipping City.
# City vaitupu not found. Skipping City.
# Processing record 327 of 611 | san policarpo
# Processing record 328 of 611 | saint george
# Processing record 329 of 611 | san miguel
# Processing record 330 of 611 | xingyi
# Processing record 331 of 611 | apad
# City umm ruwabah not found. Skipping City.
# Processing record 333 of 611 | teluknaga
# Processing record 334 of 611 | zabol
# Processing record 335 of 611 | valdivia
# Processing record 336 of 611 | sao filipe
# Processing record 337 of 611 | ipixuna
# Processing record 338 of 611 | lebu
# Processing record 339 of 611 | roald
# Processing record 340 of 611 | norman wells
# Processing record 341 of 611 | bumba
# Processing record 342 of 611 | paamiut
# Processing record 343 of 611 | castro
# Processing record 344 of 611 | sehithwa
# Processing record 345 of 611 | naze
# Processing record 346 of 611 | wanlaweyn
# Processing record 347 of 611 | dobrinka
# Processing record 348 of 611 | havoysund
# Processing record 349 of 611 | dunedin
# Processing record 350 of 611 | inhambane
# Processing record 351 of 611 | saint anthony
# Processing record 352 of 611 | esperance
# Processing record 353 of 611 | jaguaquara
# Processing record 354 of 611 | dubti
# Processing record 355 of 611 | buin
# Processing record 356 of 611 | lasa
# Processing record 357 of 611 | boyolangu
# Processing record 358 of 611 | opuwo
# Processing record 359 of 611 | belle fourche
# Processing record 360 of 611 | shakawe
# Processing record 361 of 611 | koping
# Processing record 362 of 611 | necochea
# Processing record 363 of 611 | rochegda
# Processing record 364 of 611 | talnakh
# Processing record 365 of 611 | acarau
# Processing record 366 of 611 | sistranda
# Processing record 367 of 611 | whitianga
# Processing record 368 of 611 | alta gracia
# Processing record 369 of 611 | yeniseysk
# Processing record 370 of 611 | pundaguitan
# Processing record 371 of 611 | dakar
# Processing record 372 of 611 | pangnirtung
# City nizhneyansk not found. Skipping City.
# Processing record 374 of 611 | gravdal
# Processing record 375 of 611 | mareeba
# Processing record 376 of 611 | montepuez
# Processing record 377 of 611 | sisophon
# Processing record 378 of 611 | port-gentil
# Processing record 379 of 611 | faya
# Processing record 380 of 611 | yuksekova
# Processing record 381 of 611 | vanavara
# Processing record 382 of 611 | teya
# Processing record 383 of 611 | koslan
# Processing record 384 of 611 | bubaque
# Processing record 385 of 611 | galle
# City urdzhar not found. Skipping City.
# Processing record 387 of 611 | salta
# Processing record 388 of 611 | san rafael
# Processing record 389 of 611 | nelson bay
# Processing record 390 of 611 | axim
# Processing record 391 of 611 | moron
# Processing record 392 of 611 | kulhudhuffushi
# Processing record 393 of 611 | kurilsk
# City dolbeau not found. Skipping City.
# Processing record 395 of 611 | lewisburg
# Processing record 396 of 611 | la ronge
# Processing record 397 of 611 | ankazoabo
# Processing record 398 of 611 | saint-paul
# Processing record 399 of 611 | zhigansk
# Processing record 400 of 611 | hovd
# Processing record 401 of 611 | flin flon
# Processing record 402 of 611 | shakiso
# Processing record 403 of 611 | cuiluan
# Processing record 404 of 611 | tilichiki
# Processing record 405 of 611 | port-cartier
# Processing record 406 of 611 | deputatskiy
# Processing record 407 of 611 | linhares
# Processing record 408 of 611 | verkhoyansk
# Processing record 409 of 611 | gat
# Processing record 410 of 611 | tres arroyos
# Processing record 411 of 611 | ahipara
# Processing record 412 of 611 | tolaga bay
# Processing record 413 of 611 | rio verde de mato grosso
# Processing record 414 of 611 | tsabong
# Processing record 415 of 611 | panaba
# Processing record 416 of 611 | guerrero negro
# Processing record 417 of 611 | vao
# Processing record 418 of 611 | seymchan
# Processing record 419 of 611 | manubul
# Processing record 420 of 611 | barabai
# City rungata not found. Skipping City.
# City umzimvubu not found. Skipping City.
# Processing record 423 of 611 | lebowakgomo
# Processing record 424 of 611 | anadyr
# Processing record 425 of 611 | maragogi
# Processing record 426 of 611 | saint-augustin
# Processing record 427 of 611 | atbasar
# Processing record 428 of 611 | chiang klang
# Processing record 429 of 611 | ulladulla
# Processing record 430 of 611 | itaituba
# Processing record 431 of 611 | salgueiro
# Processing record 432 of 611 | kamenka
# City grand river south east not found. Skipping City.
# Processing record 434 of 611 | dothan
# Processing record 435 of 611 | rognan
# Processing record 436 of 611 | timizart
# Processing record 437 of 611 | kimamba
# Processing record 438 of 611 | hargeysa
# Processing record 439 of 611 | hobyo
# Processing record 440 of 611 | port hueneme
# Processing record 441 of 611 | tautira
# Processing record 442 of 611 | santa cruz
# City karaul not found. Skipping City.
# Processing record 444 of 611 | sal rei
# Processing record 445 of 611 | lunsar
# Processing record 446 of 611 | ancud
# Processing record 447 of 611 | kalinagar
# Processing record 448 of 611 | sinnamary
# Processing record 449 of 611 | vikulovo
# Processing record 450 of 611 | mae chan
# Processing record 451 of 611 | nantucket
# City saleaula not found. Skipping City.
# Processing record 453 of 611 | emirdag
# Processing record 454 of 611 | ler
# Processing record 455 of 611 | ayagoz
# Processing record 456 of 611 | nishihara
# Processing record 457 of 611 | berdigestyakh
# Processing record 458 of 611 | krasnoselkup
# City ijaki not found. Skipping City.
# Processing record 460 of 611 | halden
# City uwayl not found. Skipping City.
# Processing record 462 of 611 | hirado
# Processing record 463 of 611 | berlevag
# Processing record 464 of 611 | mildura
# Processing record 465 of 611 | mairana
# Processing record 466 of 611 | baghdad
# Processing record 467 of 611 | ust-tsilma
# Processing record 468 of 611 | boueni
# Processing record 469 of 611 | luderitz
# Processing record 470 of 611 | skeldon
# Processing record 471 of 611 | langevag
# Processing record 472 of 611 | nerchinskiy zavod
# Processing record 473 of 611 | carnot
# City gurskoye not found. Skipping City.
# Processing record 475 of 611 | maniitsoq
# Processing record 476 of 611 | matara
# Processing record 477 of 611 | grand-santi
# Processing record 478 of 611 | nizhneangarsk
# Processing record 479 of 611 | kosh-agach
# Processing record 480 of 611 | ixtapa
# Processing record 481 of 611 | kyra
# Processing record 482 of 611 | kudahuvadhoo
# Processing record 483 of 611 | smoky lake
# Processing record 484 of 611 | arkhangelsk
# Processing record 485 of 611 | tazovskiy
# Processing record 486 of 611 | kutum
# Processing record 487 of 611 | maloy
# Processing record 488 of 611 | roma
# Processing record 489 of 611 | coxim
# Processing record 490 of 611 | pesqueira
# Processing record 491 of 611 | aizkraukle
# Processing record 492 of 611 | laguna
# Processing record 493 of 611 | san fernando
# Processing record 494 of 611 | ouadda
# Processing record 495 of 611 | plouzane
# Processing record 496 of 611 | northam
# Processing record 497 of 611 | coquimbo
# Processing record 498 of 611 | wukari
# Processing record 499 of 611 | svetlogorsk
# Processing record 500 of 611 | san quintin
# Processing record 501 of 611 | sulam
# Processing record 502 of 611 | thunder bay
# Processing record 503 of 611 | ostrovnoy
# Processing record 504 of 611 | wewak
# Processing record 505 of 611 | port blair
# Processing record 506 of 611 | pietarsaari
# Processing record 507 of 611 | general roca
# Processing record 508 of 611 | te anau
# Processing record 509 of 611 | ballina
# Processing record 510 of 611 | itoman
# Processing record 511 of 611 | inta
# Processing record 512 of 611 | huarmey
# Processing record 513 of 611 | safford
# Processing record 514 of 611 | vardo
# Processing record 515 of 611 | vernon
# Processing record 516 of 611 | bonavista
# Processing record 517 of 611 | ca mau
# Processing record 518 of 611 | comrat
# Processing record 519 of 611 | vallenar
# Processing record 520 of 611 | tromso
# Processing record 521 of 611 | udankudi
# Processing record 522 of 611 | izumo
# Processing record 523 of 611 | kualakapuas
# Processing record 524 of 611 | rexburg
# Processing record 525 of 611 | san felipe
# Processing record 526 of 611 | yeppoon
# Processing record 527 of 611 | mackay
# Processing record 528 of 611 | delemont
# Processing record 529 of 611 | hun
# City afmadu not found. Skipping City.
# Processing record 531 of 611 | bathsheba
# Processing record 532 of 611 | genhe
# Processing record 533 of 611 | sisimiut
# Processing record 534 of 611 | cam ranh
# Processing record 535 of 611 | warwick
# City khonuu not found. Skipping City.
# Processing record 537 of 611 | tual
# Processing record 538 of 611 | saint-georges
# Processing record 539 of 611 | whitehorse
# Processing record 540 of 611 | melendugno
# Processing record 541 of 611 | mount isa
# Processing record 542 of 611 | lahat
# City axixa do tocantins not found. Skipping City.
# Processing record 544 of 611 | austin
# Processing record 545 of 611 | baijiantan
# Processing record 546 of 611 | kabanjahe
# Processing record 547 of 611 | bakloh
# Processing record 548 of 611 | kirkwood
# Processing record 549 of 611 | emmett
# Processing record 550 of 611 | tulagi
# Processing record 551 of 611 | buckingham
# Processing record 552 of 611 | vestmanna
# Processing record 553 of 611 | gimli
# Processing record 554 of 611 | salalah
# Processing record 555 of 611 | lawrence
# Processing record 556 of 611 | koutiala
# Processing record 557 of 611 | sechenovo
# Processing record 558 of 611 | sibolga
# Processing record 559 of 611 | marienburg
# City yomitan not found. Skipping City.
# City ust-bolsheretsk not found. Skipping City.
# Processing record 562 of 611 | weihai
# Processing record 563 of 611 | athabasca
# Processing record 564 of 611 | kondinskoye
# Processing record 565 of 611 | kiunga
# Processing record 566 of 611 | raudeberg
# Processing record 567 of 611 | manavalakurichi
# Processing record 568 of 611 | bayanday
# Processing record 569 of 611 | jinchang
# Processing record 570 of 611 | alta floresta
# Processing record 571 of 611 | bonaventure
# Processing record 572 of 611 | acapulco
# Processing record 573 of 611 | great yarmouth
# City mutsamudu not found. Skipping City.
# Processing record 575 of 611 | omsukchan
# Processing record 576 of 611 | noumea
# Processing record 577 of 611 | san isidro
# Processing record 578 of 611 | cururupu
# Processing record 579 of 611 | copiapo
# Processing record 580 of 611 | goldsboro
# City maykain not found. Skipping City.
# Processing record 582 of 611 | mayo
# City urulga not found. Skipping City.
# Processing record 584 of 611 | ulaangom
# Processing record 585 of 611 | shu
# Processing record 586 of 611 | nuuk
# Processing record 587 of 611 | kemijarvi
# Processing record 588 of 611 | olenino
# Processing record 589 of 611 | los llanos de aridane
# Processing record 590 of 611 | youhao
# Processing record 591 of 611 | brae
# Processing record 592 of 611 | srednekolymsk
# Processing record 593 of 611 | arcos de la frontera
# Processing record 594 of 611 | iringa
# Processing record 595 of 611 | kushiro
# Processing record 596 of 611 | mikhaylovka
# Processing record 597 of 611 | boqueirao
# Processing record 598 of 611 | udachnyy
# Processing record 599 of 611 | luau
# Processing record 600 of 611 | airai
# Processing record 601 of 611 | cairns
# Processing record 602 of 611 | kharp
# Processing record 603 of 611 | debre birhan
# Processing record 604 of 611 | mangai
# City asayita not found. Skipping City.
# Processing record 606 of 611 | buchanan
# City tubruq not found. Skipping City.
# Processing record 608 of 611 | meulaboh
# Processing record 609 of 611 | sao jose da coroa grande
# Processing record 610 of 611 | banikoara
# Processing record 611 of 611 | mehamn

# %%
#Create the dictionary of weather information for each city, and then convert to data frame and display    
weather_dict = {
    "City": weatherCities,
    "Country": country,
    "Latitude": lat,
    "Longitude": lon,
    "Max Temp (F)": temp,
    "Humidity (%)": hum,
    "Cloudiness (%)": cloud,
    "Wind Speed (mph)": wspeed,
    "Date": edate
}
#Save the city weather data as a data frame
weather_data = pd.DataFrame(weather_dict)

# %%
#Clean the data frame by removing any entries with humidity levels over 100%
weather_data_cl = weather_data[weather_data["Humidity (%)"] <= 100]
weather_data_cl.index.name = "City ID"

#Save the city weather data as a csv
weather_data_cl.to_csv("output_data/cities.csv", sep=',', encoding='utf-8')

#Store the first date to label all the plots
start_time = weather_data_cl["Date"].iloc[0]
date = time.strftime('%m-%d-%Y', time.localtime(start_time))

#Convert epoch time into CST
weather_data_cl["Date"] = pd.to_datetime(weather_data_cl["Date"], unit='s', utc=True).dt.tz_convert('US/Central')

#Display the cleaned and formatted data frame
weather_data_cl.head()
# Out:
#                   City Country  Latitude  Longitude  Max Temp (F)  \
# City ID
# 0         Port Lincoln      AU  -34.7333   135.8667         65.46
# 1              Lerwick      GB   60.1545    -1.1494         42.80
# 2              Aklavik      CA   68.2191  -135.0107        -33.77
# 3        Bambanglipuro      ID   -7.9500   110.2833         63.61
# 4              Ushtobe      KZ   45.2514    77.9838         17.91
#
#          Humidity (%)  Cloudiness (%)  Wind Speed (mph)  \
# City ID
# 0                  80             100             15.97
# 1                  72             100             35.72
# 2                  67               0              6.91
# 3                  84              90              6.53
# 4                  84               5              7.96
#
#                              Date
# City ID
# 0       2022-02-05 09:24:25-06:00
# 1       2022-02-05 09:25:37-06:00
# 2       2022-02-05 09:22:55-06:00
# 3       2022-02-05 09:25:38-06:00
# 4       2022-02-05 09:25:38-06:00

# %%
#Define a function that will create a scatter plot and save it
def scattered(xlabel, ylabel, lat_range, date, savename):
    plt.figure()
    plt.scatter(weather_data_cl[xlabel], weather_data_cl[ylabel], marker = "o", facecolors="skyblue", edgecolors="black")
    plt.grid()
    plt.xlabel(xlabel)
    plt.xlim(lat_range[0], lat_range[1])
    plt.ylabel(ylabel)
    plt.title(f"{ylabel} vs {xlabel} ({date})")
    
    #Save the figure
    plt.savefig("output_data/"+ savename)
    
    #Display the figure
    plt.show()

# %%
# Temperature (F) vs. Latitude

#Define plot specific information
xlabel = "Latitude"
ylabel = "Max Temp (F)"
savename = "MaxTvsLat"

#Call on the user-defined scattered function
scattered(xlabel, ylabel, lat_range, date, savename)

# %%
# Humidity (%) vs. Latitude

#Define plot specific information
xlabel = "Latitude"
ylabel = "Humidity (%)"
savename = "HumVsLat"

#Call on the user-defined scattered function
scattered(xlabel, ylabel, lat_range, date, savename)

# %%
# Cloudiness (%) vs. Latitude

#Define plot specific information
xlabel = "Latitude"
ylabel = "Cloudiness (%)"
savename = "CloudVsLat"

#Call on the user-defined scattered function
scattered(xlabel, ylabel, lat_range, date, savename)

# %%
# Wind Speed (mph) vs. Latitude

#Define plot specific information
xlabel = "Latitude"
ylabel = "Wind Speed (mph)"
savename = "WSpdVsLat"

#Call on the user-defined scattered function
scattered(xlabel, ylabel, lat_range, date, savename)

# %%
#Create separate data frames for the northern and southern hemispheres
north_weather_data = weather_data_cl[weather_data_cl["Latitude"] >= 0]
south_weather_data = weather_data_cl[weather_data_cl["Latitude"] < 0]

#Create a data frame for the xlim values for the scatter plots below
xaxis = pd.DataFrame({"Northern": (0, 80), "Southern": (-60, 0)})

# %%
#Define a function that will output the r-value, scatter plot, linear regression line, and linear regression equation

def linreg(hemisphere, xlabel, ylabel, annoloc, savename, date):

    if hemisphere == "Northern":
        xvalues = north_weather_data[xlabel]
        yvalues = north_weather_data[ylabel]
    else:     
        xvalues = south_weather_data[xlabel]
        yvalues = south_weather_data[ylabel]
        
    #Format the scatter plot
    plt.figure()
    plt.title(f"{hemisphere} Hemisphere: {ylabel} vs {xlabel} ({date})")
    xlim = xaxis[hemisphere] #pull the xlim values from a data frame
    plt.xlim(xlim)
    plt.scatter(xvalues, yvalues, marker = "o", facecolors="skyblue", edgecolors="black")
    plt.grid()
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    #Calculate everything needed for the linear regression line
    (slope, intercept, rvalue, pvalue, stdder) = linregress(xvalues, yvalues)
    line = slope * xvalues + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    #Format the linear regression line plot
    plt.plot(xvalues, line, color = "red")
    plt.annotate(line_eq, annoloc, fontsize = 15, color = "red")

    #Save the figure
    plt.savefig("output_data/"+ savename)
        
    #Show r-value and the plot
    print(f"The r-value is {round(rvalue, 4)}")
    plt.show();

# %%
# Northern Hemisphere - Temperature (F) vs. Latitude

#Define plot specific information
hemisphere = "Northern"
xlabel = "Latitude"
ylabel = "Max Temp (F)"
savename = "N_MaxTvsLat"
annoloc = (10,-20)   #annotation location for the linear regression equation

#Call on the user-defined linreg function
linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)

print("analysis")
# Out:
# The r-value is -0.8658
# analysis

# %%
#Southern Hemisphere - Temperature (F) vs. Latitude

#Define plot specific information
hemisphere = "Southern"
xlabel = "Latitude"
ylabel = "Max Temp (F)"
savename = "S_MaxTvsLat"
annoloc = (-55,75)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.5577

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude

#Define plot specific information
hemisphere = "Northern"
xlabel = "Latitude"
ylabel = "Humidity (%)"
savename = "N_HumVsLat"
annoloc = (5,40)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.4864

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude

#Define plot specific information
hemisphere = "Southern"
xlabel = "Latitude"
ylabel = "Humidity (%)"
savename = "S_HumVsLat"
annoloc = (-30,45)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.2052

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude

#Define plot specific information
hemisphere = "Northern"
xlabel = "Latitude"
ylabel = "Cloudiness (%)"
savename = "N_CloudVsLat"
annoloc = (45,30)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.3223

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude

#Define plot specific information
hemisphere = "Southern"
xlabel = "Latitude"
ylabel = "Cloudiness (%)"
savename = "S_CloudVsLat"
annoloc = (-55,65)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.2831

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude

#Define plot specific information
hemisphere = "Northern"
xlabel = "Latitude"
ylabel = "Wind Speed (mph)"
savename = "N_WSpdVsLat"
annoloc = (20,17.5)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is 0.0224

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude

#Define plot specific information
hemisphere = "Southern"
xlabel = "Latitude"
ylabel = "Wind Speed (mph)"
savename = "S_WSpdVsLat"
annoloc = (-30, 15.5)   #annotation location for the linear regression equation

linreg(hemisphere, xlabel, ylabel, annoloc, savename, date)
# Out:
# The r-value is -0.2941
